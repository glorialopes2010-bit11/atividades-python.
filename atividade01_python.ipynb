# %% [markdown]
# # Atividade 01 — Introdução ao Python

# %%
print("Minha primeira atividade no Google Colab")
print("Aprendeno Python e GitHub")
# Out:
# Minha primeira atividade no Google Colab
# Aprendeno Python e GitHub

# %%
disciplina = input("Digite a disciplina estudada:")
conteúdo = input("Digite o conteúdo estudado:")
atividade = input("Digite o número da atividade:")
print("---Infomações da atividade---")
print("Disciplina:",disciplina)
print("Conteúdo:",conteúdo)
print("Atividade:",atividade)
# Out:
# Digite a disciplina estudada:Programação
# Digite o conteúdo estudado:Introdução a Python
# Digite o número da atividade:01
# ---Infomações da atividade---
# Disciplina: Programação
# Conteúdo: Introdução a Python
# Atividade: 01
